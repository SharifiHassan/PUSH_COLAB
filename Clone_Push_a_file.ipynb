# %% [markdown]
# # ✅ PUSH a file FROM GOOGLE DRIVE TO EXISTING GITHUB REPO

# %% [markdown]
# ## 📂 Step 1: Mount Google Drive in Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##🔹 Step 2: Clone Your GitHub Repo into Colab
#
# (If you haven’t already cloned it)

# %%
import getpass

token = getpass.getpass("Enter your GitHub token: ")
username = "sharifihassan"

repo = "push_colab"
repo_url = f"https://{token}@github.com/{username}/{repo}.git"

# !git clone {repo_url}
# %cd ml_course
# Out:
# Enter your GitHub token: ··········
# Cloning into 'push_colab'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# [Errno 2] No such file or directory: 'ml_course'
# /content

# %% [markdown]
# ## 🔹 Step 3: Copy the File from Google Drive
#
# First, locate the file:

# %%
# !ls /content/drive/MyDrive/Colab_Notebooks/
# Out:
#  Clone_Push_a_file.ipynb  'PUSH_a_file_in _existing_repo.ipynb'   README.md
# 'Day 001.ipynb'		   PUSH_COLAB.ipynb

# %% [markdown]
# Then copy the file to your cloned repo folder:

# %% [markdown]
# ## 🔹 Step 4: Set Git Identity

# %%
# !cp /content/drive/MyDrive/Colab_Notebooks/Clone_Push_a_file.ipynb /content/push_colab//

# %%
# %cd /content/push_colab/

# !git add Clone_Push_a_file.ipynb
# !git commit -m "Add Clone to add a file to an existing repo from Google Drive"
# !git push origin main
# Out:
# /content/push_colab
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@53612dfc03ba.(none)')
# Everything up-to-date

# %% [markdown]
# ## 🔹 Step 4: Add, Commit, and Push the New File

# %% [markdown]
# ## 🛠️ 🔹 Step 2: Create Local Folder and Copy File
#
# Let’s say the file in Drive is at:
#
# /content/drive/MyDrive/colab_notebooks/push_colab.ipynb
#
#
# And your repo folder isgoing to be:
#
# /content/push_colab/

# %%
# !mkdir -p /content/PUSH_COLAB
# !cp /content/drive/MyDrive/Colab_Notebooks/PUSH_COLAB.ipynb /content/PUSH_COLAB/
# %cd /content/PUSH_COLAB/
# Out:
# /content/PUSH_COLAB

# %%
# !find /content/drive/MyDrive/Colab_Notebooks/ -name "PUSH_COLAB.ipynb"
# Out:
# /content/drive/MyDrive/Colab_Notebooks/PUSH_COLAB.ipynb

# %% [markdown]
# ## 🔹 Step 3: Initialize Git Repo (if not done already)

# %% [markdown]
# ## 🔹 Step 4: Set Git Identity

# %%
# !ls /content/drive/MyDrive/Colab_Notebooks/
# !ls /content/PUSH_COLAB/
# Out:
# 'Day 001.ipynb'			        PUSH_a_file.ipynb   README.md
# 'PUSH_a_file_in _existing_repo.ipynb'   PUSH_COLAB.ipynb
# PUSH_COLAB.ipynb

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/push_colab/.git/

# %%
# !ls /cotent/push_colab
# Out:
# ls: cannot access '/cotent/push_colab': No such file or directory

# %% [markdown]
# ## 🔹 Step 4: Set Git Identity

# %%
# !git config --global user.name "sharifihassan"
# !git config --global user.email "sharifihsn@gmail.com"

# %%
# !git config --global init.defaultBranch main

# %% [markdown]
# ## 🔹 Step 5: Connect to GitHub via Token

# %%
import getpass

token = getpass.getpass("Enter your GitHub token: ")
username = "sharifihassan"
repo = "PUSH_COLAB"

remote_url = f"https://{token}@github.com/{username}/{repo}.git"
# !git remote add origin $remote_url
# Out:
# Enter your GitHub token: ··········

# %%
# !git add PUSH_COLAB.ipynb
# !git commit -m "Add push_colab notebook from Google Drive"
# !git branch -M main
# !git push -u origin main --force
# Out:
# On branch main
# nothing to commit, working tree clean
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 2.94 KiB | 2.94 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/SharifiHassan/push_colab.git
# To https://github.com/sharifihassan/PUSH_COLAB.git
#  + dc831d8...283a7fd main -> main (forced update)
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %% [markdown]
# ## ✅ DONE!
# Visit your repo:
# 👉 https://github.com/sharifihassan/push_colab
#
# Let me know if you'd like to push more files or automate this with one reusable cell.

# %%
# !ls
