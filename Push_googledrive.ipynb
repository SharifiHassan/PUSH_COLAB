# %%
import getpass

username = "sharifihassan"
repo = "push_colab"
token = getpass.getpass("Enter your GitHub token: ")

# !git clone https://{token}@github.com/{username}/{repo}.git
# Out:
# Enter your GitHub token: ··········
# Cloning into 'push_colab'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 21 (delta 4), reused 19 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 14.32 KiB | 14.32 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %% [markdown]
# # ✅ PUSH A FILE FROM GOOGLE DRIVE TO GITHUB
# Let’s say your file is in Drive as:
#
# 📄 pull_push_steps.ipynb
#
# 📂 located at: /content/drive/MyDrive/pull_push_steps.ipynb
#
# You want it added to your repo: push_colab
#
# #🪜 STEP-BY-STEP GUIDE
#
# #🔹 Step 1: Mount Google Drive
# Run this first:
#
# and then
#
# 🔐 Click the link and enter the code to connect your Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 🔹 Step 2: Copy the File from Drive to Your Git Repo Folder
#
# Replace the path if needed:
#
# # ✅ This puts your file inside the local Git repo folder.
#
# to Handle Spaces in File/Folder Names
#
# ✅  Escape the space with a backslash
#
# `!cp /content/drive/MyDrive/Colab\ Notebooks/pull_steps.ipynb /content/push_colab/`
#
# ✅ This puts your file inside the local Git repo folder.

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/Push_steps.ipynb /content/push_colab/

# %% [markdown]
# # 🔹 Step 3: Move into the Repo Folder

# %%
# %cd /content/push_colab
# Out:
# /content/push_colab

# %% [markdown]
# # 🔹 Step 4: Check the File Is There
#
# You should see pull_push_steps.ipynb listed.

# %%
# !ls
# Out:
# Clone_Push_a_file.ipynb  PUSH_COLAB.ipynb
# pull_push_steps.ipynb	 Push_steps.ipynb

# %% [markdown]
# #

# %% [markdown]
# # 🔹 Step 5: Set Your Git Info (Only Needed Once)

# %%
# !git config --global user.name "Sharifihassan"
# !git config --global user.email "sharifihsn@gmail.com"

# %% [markdown]
# # 🔹 Step 6: Add, Commit, and Push the File

# %%
# !git add Push_steps.ipynb
# !git commit -m "Add pull_push_steps notebook from Google Drive"
# !git push origin main
# Out:
# [main 24063ed] Add pull_push_steps notebook from Google Drive
#  1 file changed, 1 insertion(+)
#  create mode 100644 Push_steps.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 6.37 KiB | 6.38 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/SharifiHassan/push_colab.git
# To https://github.com/sharifihassan/push_colab.git
#    720afd8..24063ed  main -> main

# %% [markdown]
# #🎉 That’s It!
# Your Drive file is now versioned and uploaded to your GitHub repo:
#
# 👉 https://github.com/sharifihassan/push_colab
